# %% [markdown]
# # Movie Posters Dataset generation

# %%
import pandas as pd
import requests
import os
from dotenv import load_dotenv
import numpy as np
import tqdm
import ast

# %% [markdown]
# ## Data Related

# %%
root = os.path.dirname(os.path.abspath(os.getcwd()))

# %%
load_dotenv(os.path.join(root, "secrets.env"))
# Out:
# True

# %%
TMBD_API = os.getenv('TMDB_API')

# %% [markdown]
# ## Get MovieDBs Genre List

# %%
def query_genres():
    url = f"https://api.themoviedb.org/3/genre/movie/list?api_key={TMBD_API}&language=en-US"
    req = requests.get(url)
    genres = {}
    for entry in req.json()["genres"]:
        genres[entry["id"]] = entry["name"]
    return genres

# %%
genres = query_genres()

# %%
genres
# Out:
# {28: 'Action',
#  12: 'Adventure',
#  16: 'Animation',
#  35: 'Comedy',
#  80: 'Crime',
#  99: 'Documentary',
#  18: 'Drama',
#  10751: 'Family',
#  14: 'Fantasy',
#  36: 'History',
#  27: 'Horror',
#  10402: 'Music',
#  9648: 'Mystery',
#  10749: 'Romance',
#  878: 'Science Fiction',
#  10770: 'TV Movie',
#  53: 'Thriller',
#  10752: 'War',
#  37: 'Western'}

# %% [markdown]
# ## Get MovieDBs Movie Top 500 Page Results

# %%
MAX_PAGE_RESULTS = 500

# %%
def query_popular(genres: dict, page: int = 1):
    url = f"https://api.themoviedb.org/3/movie/popular?api_key={TMBD_API}&language=en-US&page={page}"
    req = requests.get(url)
    try:
        match req.status_code:
            case 200:
                df = pd.DataFrame.from_dict(req.json()["results"])
            case _:
                print(req.json())
    except Exception as e:
        print(f"{e}")
    return df

# %%
data = pd.DataFrame()

# %%
for i in tqdm.tqdm(range(MAX_PAGE_RESULTS)):
    temp = query_popular(genres, i + 1)
    data = pd.concat([data, temp], ignore_index=True )
# Out:
# 100%|██████████| 500/500 [01:01<00:00,  8.19it/s]

# %%
data
# Out:
#       adult                     backdrop_path                genre_ids
# 0     False  /9n2tJBplPbgR2ca05hS5CKXwP2c.jpg  [16, 12, 10751, 14, 35]  \
# 1     False  /5i6SjyDbDWqyun8klUuCxrlFbyw.jpg                 [18, 28]
# 2     False  /ovM06PdF3M8wvKb06i4sjW3xoww.jpg            [878, 12, 28]
# 3     False  /vSUls0b7dNhC7tJoExF1MBYWWyh.jpg  [16, 35, 10751, 12, 14]
# 4     False  /bT3IpP7OopgiVuy6HCPOWLuaFAd.jpg           [35, 9648, 28]
# ...     ...                               ...                      ...
# 9995  False  /3WKrovKHfJTJzYOqpYtCftr9iDX.jpg                     [35]
# 9996  False  /vzjgieFzT8ySkMdxdu3kIf4caZS.jpg                     [53]
# 9997  False  /tdgce7OwwUwF7atRiar1y1AS6eh.jpg     [18, 28, 35, 53, 80]
# 9998  False  /6ZNqWfUXdxiNVqwgO2doLlkmgQc.jpg         [28, 80, 18, 53]
# 9999  False  /xNlNH4Rv0Grba4HR2XIZwgWUFlE.jpg         [16, 12, 28, 14]
#
#           id original_language                               original_title
# 0     502356                en                  The Super Mario Bros. Movie  \
# 1     677179                en                                    Creed III
# 2      76600                en                     Avatar: The Way of Water
# 3     816904                es                                       Momias
# 4     638974                en                             Murder Mystery 2
# ...      ...               ...                                          ...
# 9995  121342                it  Giovannona Coscialunga disonorata con onore
# 9996   11983                en                                Proof of Life
# 9997   26715                en                                   Bitch Slap
# 9998  139567                en                               Fire with Fire
# 9999   97787                ja                               映画 デジモンアドベンチャー
#
#                                                overview  popularity
# 0     While working underground to fix a water main,...   10058.912  \
# 1     After dominating the boxing world, Adonis Cree...    7413.386
# 2     Set more than a decade after the events of the...    6686.292
# 3     Through a series of unfortunate events, three ...    3562.319
# 4     After starting their own detective agency, Nic...    4873.950
# ...                                                 ...         ...
# 9995  When a judge shuts down a high profile cheese ...      14.619
# 9996  Alice hires a professional negotiator to obtai...      13.690
# 9997  Three bad girls (a down-and-out stripper, a dr...      15.441
# 9998  A fireman takes an unexpected course of action...      15.442
# 9999  Two children receive a strange egg that hatche...      13.229
#
#                            poster_path release_date
# 0     /qNBAXBIQlnOThrVvA6mA2B5ggV6.jpg   2023-04-05  \
# 1     /vJU3rXSP9hwUuLeq8IpfsJShLOk.jpg   2023-03-01
# 2     /t6HIqrRAclMCA60NsSmeqe9RmNV.jpg   2022-12-14
# 3      /qVdrYN8qu7xUtsdEFeGiIVIaYd.jpg   2023-01-05
# 4     /swzMoIVn6xjB857ziYJ8KBV440g.jpg   2023-03-28
# ...                                ...          ...
# 9995  /vkF8VLrazGtk9OjdEhihG6kKAhP.jpg   1973-04-12
# 9996  /yw8x2i3vaHZZzpvqvF75E8q2N6M.jpg   2000-12-08
# 9997  /bFOmE3zCFU01TuomOOwClAWdvOD.jpg   2009-05-16
# 9998  /kziBJGQFo9f0Vkj9s37qI0G9I0I.jpg   2012-08-31
# 9999  /tn65LMkjjFFRdhwV2eSFH3WRlwA.jpg   1999-03-06
#
#                             title  video  vote_average  vote_count
# 0     The Super Mario Bros. Movie  False           7.5         410
# 1                       Creed III  False           7.3         870
# 2        Avatar: The Way of Water  False           7.7        6873
# 3                         Mummies  False           7.1         125
# 4                Murder Mystery 2  False           6.4         564
# ...                           ...    ...           ...         ...
# 9995        Giovannona Long-Thigh  False           4.9          31
# 9996                Proof of Life  False           6.1         682
# 9997                   Bitch Slap  False           4.7         252
# 9998               Fire with Fire  False           5.7         600
# 9999            Digimon Adventure  False           7.6          68
#
# [10000 rows x 14 columns]

# %% [markdown]
# ## check if any genre id columns are empty

# %%
data[data["genre_ids"].astype(bool) == False]
# Out:
#       adult                     backdrop_path genre_ids       id
# 1605  False  /4hPKEU0DfkPSGgDRg0mBje5BfJ0.jpg        []   185708  \
# 2121  False  /ek4BlZ4ZCdVannkLz7VYjvWDKZb.jpg        []   887074
# 2618  False  /fsBnJV0K5bcmzUAwL47A9FqoKae.jpg        []   105812
# 2980  False  /hhDGtayED4HqhTrDRO4yqz9MVGG.jpg        []   687558
# 3939  False  /klmGn6q0fQNfBFNLDK4FY59pv8l.jpg        []   902870
# 4456  False  /2F4SaH5pgD0zEzdZD8Dx1LMqptP.jpg        []   592742
# 5255  False  /rBHk5eFF4Flc5dOriPwBqp03qmQ.jpg        []   658494
# 5502  False  /vFYgAENLOeD2sHCAEQfx5rDPjRt.jpg        []   312750
# 5522  False  /llLsvucZRrpjTMpz7Fczp7vZut4.jpg        []   449302
# 5547  False  /pAEBusvtIgzQ5eTgV54PgN0a3qp.jpg        []   729791
# 5760  False  /2ljq2PDTmh300QzjP840tpc9vH1.jpg        []   501007
# 6082  False  /gZJa0Yv0y8YVAsX8jo6htwZjcia.jpg        []   511420
# 6305  False  /i11WwKGAE9OZEha4UWjpdZi5OJJ.jpg        []  1104580
# 6826  False  /sPqSpkoZ4fIcB3TmEbSNNMGQhez.jpg        []  1046125
# 7601  False  /nkfb61ViPndKto7ulj9qNsUH6FA.jpg        []   479304
# 8508  False  /ktZVhoy2XdefLwzTVWVRpUR08Qk.jpg        []  1056272
# 8944  False  /zN8JScKU8fInoCCxlVApffVZyBm.jpg        []  1096128
# 9637  False  /6tIFRX3xy7TCEPRBeHmRi10UDYi.jpg        []   967473
#
#      original_language                  original_title
# 1605                ja                       団鬼六　美女縄化粧  \
# 2121                zh                         屠魔：王者征途
# 2618                cn                           青樓十二房
# 2980                ko                       여자전쟁:도기의난
# 3939                zh                            狙击之王
# 4456                ja  私の奴隷になりなさい 第2章 「ご主人様と呼ばせてください」
# 5255                ja                 ホームジャック　トライアングル
# 5502                ml                   Rathinirvedam
# 5522                zh                           嬌妻四艷鬼
# 5547                ja                     美女奉行　おんな牢秘抄
# 5760                en                              It
# 6082                es          Muchachos en la azotea
# 6305                ja        NJPW Sakura Genesis 2023
# 6826                ja                    淫行フェチ 変態うねり尻
# 7601                es                          Armero
# 8508                en                        Euphoria
# 8944                ru     ACA 155: Karginov vs. Silva
# 9637                ja          DPMI-019 キャンギャル狂想脚 美月恋
#
#                                                overview  popularity
# 1605  Miki is the daughter of an affluent family. Sh...      57.925  \
# 2121  Lord of Darkness Artha was born from human str...      37.755
# 2618  Madam Five and carpenter Kong work together ma...      36.173
# 2980  There is a visitor for local herb gatherer Dog...      29.904
# 3939  The Salvation Society is the most powerful cri...      18.311
# 4456  Meguro, who works for the advertising design c...      17.081
# 5255  A female police officer arrests serial killer/...      20.760
# 5502  The story takes place in a small village surro...      22.206
# 5522  Some female ghosts seduce and kill trespassers...      31.049
# 5547  A woman calling herself Princess Oryu enters t...      22.104
# 5760  A blind man reports on an eclipse, a light phe...      21.541
# 6082  Sergio and Octavio discover each other in a ga...      20.706
# 6305  Professional wrestling event promoted by New J...      20.217
# 6826  Honoka, a daughter who takes care of her self-...      19.064
# 7601                                                         13.455
# 8508  Artist and filmmaker Julian Rosefeldt creates ...      16.591
# 8944  ACA 159: Karginov vs. Silva was a mixed martia...      15.785
# 9637                                                         20.894
#
#                            poster_path release_date
# 1605  /kuIf5deP5PsasS4rdaC6eA4AyDW.jpg   1983-12-02  \
# 2121  /174uwJ0uhlWHbp8FPZRth7SMv6d.jpg   2021-10-18
# 2618  /53AdAWdL7pJnWzvfSfDq30MJaFw.jpg   1994-09-15
# 2980  /pUnZK0uumzFD068kdcHMBTj9YQq.jpg   2016-03-24
# 3939  /ecIRwkWHuAA830HlO7u5ofRp4uM.jpg   2021-11-19
# 4456  /isxWYeKRNaJ84hN46CCPyNtxXuW.jpg   2018-09-29
# 5255  /v9SV2VwBwg401wUZkfq8F2EAMWR.jpg   2018-03-02
# 5502  /sTkMzvqmCYAYVqZxJhlxubvBYJl.jpg   1978-03-08
# 5522  /nODjK3FePbOQvQrLxInHoCIqAEA.jpg   1994-03-26
# 5547  /5rUqxpyE3YbnBK721euV0IkbNq3.jpg   1995-03-24
# 5760  /cBu6jlMvlaB3H8oKL8gNcOqzU4C.jpg   2017-12-14
# 6082  /j8GjrqMPmEmdxqNEkA8LhLg1TAh.jpg   2016-03-05
# 6305  /iZTbmXHkEK8wrX1mAkfxOHhTwUZ.jpg   2023-04-08
# 6826  /xBgYpdaWfAB9zOQhY6mbnT6eXLA.jpg   2013-06-11
# 7601  /1yhaCCHSZ0fs5cbLDLO1XYEinRv.jpg   2017-01-04
# 8508  /xvIZd7D8QBBirIfTv3fwh2DyRht.jpg   2022-11-29
# 8944  /faor2fyXW4JaRBjMJ5xVRgsgaOB.jpg   2023-04-08
# 9637  /5iIX4vLstOcWayN1DumWpwlNudr.jpg   2017-06-25
#
#                                title  video  vote_average  vote_count genres
# 1605         Beauty Rope Cosmetology  False           1.0           1     []
# 2121                       The Sword  False           5.3           3     []
# 2618      Ancient Chinese Whorehouse  False           5.0           1     []
# 2980   Female War: Doggie's Uprising  False           0.0           0     []
# 3939                      The Sniper  False           4.0           2     []
# 4456                    Be My Master  False           6.9           7     []
# 5255               Homejack Triangle  False           6.5           2     []
# 5502                   Rathinirvedam  False           9.5           2     []
# 5522                    Snake Beauty  False           0.0           0     []
# 5547     Musume Bugyo On-na Ro Hisho  False           2.5           2     []
# 5760                              It  False           0.0           0     []
# 6082             Boys on the Rooftop  False           4.4           5     []
# 6305        NJPW Sakura Genesis 2023  False           0.0           0     []
# 6826  Inkô fechi: Hentai uneri shiri  False           0.0           0     []
# 7601                          Armero  False           7.7          35     []
# 8508                        Euphoria  False           0.0           0     []
# 8944     ACA 155: Karginov vs. Silva  False           0.0           0     []
# 9637          DPMI-019 キャンギャル狂想脚 美月恋  False           0.0           0     []

# %%
data = data[data["genre_ids"].astype(bool)]

# %% [markdown]
# ## Data Cleaning

# %%
data.isnull().sum(axis = 0)
# Out:
# adult                0
# backdrop_path        0
# genre_ids            0
# id                   0
# original_language    0
# original_title       0
# overview             0
# popularity           0
# poster_path          0
# release_date         0
# title                0
# video                0
# vote_average         0
# vote_count           0
# genres               0
# dtype: int64

# %%
# drop rows that contain null values
data.dropna(inplace=True)

# %%
data.shape
# Out:
# (9739, 15)

# %%
# convert list of genre ids to string
# [53, 35, 80] -> ["Thriller", "Comedy", "Crime"]

# %%
def convert_genre_ids(ids: list, genres: dict):
    genres_list = []
    for key in ids:
        genres_list.append(genres.get(key))
    return genres_list

# %%
data["genres"] = data["genre_ids"].apply(lambda x: convert_genre_ids(x, genres))

# %%
# drop rows that contain null values
data.dropna(inplace=True)

# %%
def extract_top_genre_id(x):
    return [x[0]]

# %%
# convert list of genre names to top genre
# ["Thriller", "Comedy", "Crime"] -> ["Thriller"]

# %%
data["genres_single"] = data["genres"].apply(lambda x: extract_top_genre_id(x))

# %%
data.head(5)
# Out:
#    adult                     backdrop_path                genre_ids      id
# 0  False  /9n2tJBplPbgR2ca05hS5CKXwP2c.jpg  [16, 12, 10751, 14, 35]  502356  \
# 1  False  /5i6SjyDbDWqyun8klUuCxrlFbyw.jpg                 [18, 28]  677179
# 2  False  /ovM06PdF3M8wvKb06i4sjW3xoww.jpg            [878, 12, 28]   76600
# 3  False  /vSUls0b7dNhC7tJoExF1MBYWWyh.jpg  [16, 35, 10751, 12, 14]  816904
# 4  False  /bT3IpP7OopgiVuy6HCPOWLuaFAd.jpg           [35, 9648, 28]  638974
#
#   original_language               original_title
# 0                en  The Super Mario Bros. Movie  \
# 1                en                    Creed III
# 2                en     Avatar: The Way of Water
# 3                es                       Momias
# 4                en             Murder Mystery 2
#
#                                             overview  popularity
# 0  While working underground to fix a water main,...   10058.912  \
# 1  After dominating the boxing world, Adonis Cree...    7413.386
# 2  Set more than a decade after the events of the...    6686.292
# 3  Through a series of unfortunate events, three ...    3562.319
# 4  After starting their own detective agency, Nic...    4873.950
#
#                        poster_path release_date                        title
# 0  qNBAXBIQlnOThrVvA6mA2B5ggV6.jpg   2023-04-05  The Super Mario Bros. Movie  \
# 1  vJU3rXSP9hwUuLeq8IpfsJShLOk.jpg   2023-03-01                    Creed III
# 2  t6HIqrRAclMCA60NsSmeqe9RmNV.jpg   2022-12-14     Avatar: The Way of Water
# 3   qVdrYN8qu7xUtsdEFeGiIVIaYd.jpg   2023-01-05                      Mummies
# 4  swzMoIVn6xjB857ziYJ8KBV440g.jpg   2023-03-28             Murder Mystery 2
#
#    video  vote_average  vote_count
# 0  False           7.5         410  \
# 1  False           7.3         870
# 2  False           7.7        6873
# 3  False           7.1         125
# 4  False           6.4         564
#
#                                             genres      genres_single
# 0  [Animation, Adventure, Family, Fantasy, Comedy]        [Animation]
# 1                                  [Drama, Action]            [Drama]
# 2             [Science Fiction, Adventure, Action]  [Science Fiction]
# 3  [Animation, Comedy, Family, Adventure, Fantasy]        [Animation]
# 4                        [Comedy, Mystery, Action]           [Comedy]

# %%
# remove leading '/' from poster_path
data["poster_path"] = data["poster_path"].apply(lambda x: x.replace("/", ""))

# %% [markdown]
# ## Save Raw CSV

# %%
data = data.reset_index(drop=True)

# %%
data_csv = os.path.join(root, "data", "raw_data.csv")

# %%
data.to_csv(data_csv)
