# %%
import os
import sys
import pandas as pd
import torch
import numpy as np
import matplotlib.pyplot as plt
import logging
from torch.utils.data import DataLoader
import multiprocessing
import tqdm
from ast import literal_eval
from annoy import AnnoyIndex
import cv2
import torchvision.transforms as transforms

from torchvision import transforms
from umap import UMAP
import plotly.express as px
from collections import Counter

# %%
dir_path = os.path.dirname(os.path.abspath(os.getcwd()))

# %%
sys.path.append(os.path.join(dir_path, "src"))

# %%
from data_module import ImageDataModule
from resnet import Resnet50
from utils import collate_batch
from dataset import ImageDataset

# %%
ckpt = os.path.join(dir_path, "notebooks","lightning_logs","version_39","checkpoints","epoch=7-step=1952.ckpt")

# %%
model = Resnet50.load_from_checkpoint(ckpt, embedding_size=512, num_classes=19)
# Out:
# /home/main/.local/share/virtualenvs/cosc525_final_project-aJH_ag1x/lib/python3.10/site-packages/torchvision/models/_utils.py:135: UserWarning: Using 'weights' as positional parameter(s) is deprecated since 0.13 and may be removed in the future. Please use keyword parameter(s) instead.
#   warnings.warn(
# /home/main/.local/share/virtualenvs/cosc525_final_project-aJH_ag1x/lib/python3.10/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet50_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet50_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)

# %%
def load_image_arrary(file):
        path = os.path.join(dir_path, "images", "raw")
        image = cv2.imread(f"{path}/{file}")
        image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
        normalize = transforms.Normalize(
                mean=[0.485, 0.456, 0.406],
                std=[0.229, 0.224, 0.225]
        )
        transformations = transforms.Compose([
            transforms.ToPILImage(),
            transforms.Resize((224, 224)),
            transforms.RandomHorizontalFlip(),
            transforms.ToTensor(),
            normalize
        ]) 
        image = transformations(image)
        return image.unsqueeze(0) # add a batch channel

# %%
def extract_embedding(model, image):
    model.eval()
    with torch.no_grad():
        embedding = model(image)
    return embedding[0]

# %%
index_df = pd.read_csv("metadata.csv", index_col=0)

# %%
embeddings = []

# %%
# for i, row in index_df[index_df["genre"] == f"['{genre}']"].iterrows():
for i, row in tqdm.tqdm(index_df.iterrows()):
    image = load_image_arrary(row["image_name"])
    query_embedding = extract_embedding(model, image)
    embeddings.append(query_embedding)
# Out:
# 9739it [14:02, 11.56it/s]

# %%
umap_3d = UMAP(n_components=5, init='random', random_state=0)

# %%
list_embeddings = [x.tolist() for x  in embeddings]

# %%
list_embeddings[0]
# Out:
# [0.017839781939983368,
#  -0.0020168619230389595,
#  -0.09078569710254669,
#  -0.10151342302560806,
#  0.027614912018179893,
#  -0.0261685810983181,
#  0.02291029505431652,
#  -0.1472741961479187,
#  0.03172680735588074,
#  0.0617537647485733,
#  0.0513116791844368,
#  0.013941647484898567,
#  -0.004079429432749748,
#  -0.0003509853850118816,
#  -0.026556581258773804,
#  -0.026939833536744118,
#  -0.0055480096489191055,
#  0.0160692036151886,
#  -0.010538513772189617,
#  -0.0367879755795002,
#  0.01898203231394291,
#  0.0419270396232605,
#  0.01714361272752285,
#  4.485963290790096e-05,
#  -0.013616516254842281,
#  0.06261464208364487,
#  -0.036758653819561005,
#  -0.026074083521962166,
#  0.009408047422766685,
#  -0.0034446308854967356,
#  0.034473519772291183,
#  0.07049272209405899,
#  -0.012973318807780743,
#  0.029872125014662743,
#  0.08257605880498886,
#  0.0032051524613052607,
#  -0.03974813222885132,
#  -0.004831834230571985,
#  -0.01249630842357874,
#  0.02724573016166687,
#  -0.014259607531130314,
#  -0.007297751028090715,
#  -0.08242394030094147,
#  0.0029201158322393894,
#  0.0007878748001530766,
#  -0.040996212512254715,
#  0.00782392080873251,
#  -0.028472458943724632,
#  -0.03677947819232941,
#  -0.09865595400333405,
#  0.047492917627096176,
#  -0.03214822709560394,
#  -0.007240015082061291,
#  -0.011092412285506725,
#  -0.08443523943424225,
#  -0.005256160162389278,
#  -0.07072967290878296,
#  0.02177325449883938,
#  -0.010824640281498432,
#  0.009751991368830204,
#  -0.02228614129126072,
#  -0.016245387494564056,
#  0.029739759862422943,
#  0.06995318830013275,
#  0.06313436478376389,
#  -0.03785046935081482,
#  -0.05363694578409195,
#  0.04462599381804466,
#  -0.020049534738063812,
#  -0.07892002165317535,
#  0.004474022891372442,
#  0.015193367376923561,
#  0.002117154421284795,
#  0.005971916485577822,
#  0.007272625807672739,
#  -0.009485290385782719,
#  0.005819948390126228,
#  0.003457866609096527,
#  0.026708563789725304,
#  -0.001144576701335609,
#  0.04057063162326813,
#  -0.06850339472293854,
#  -0.04217451438307762,
#  0.0004437914758455008,
#  0.04046060889959335,
#  -0.06907448917627335,
#  -0.05967076122760773,
#  0.015611885115504265,
#  -0.028453806415200233,
#  0.03680969402194023,
#  0.023427540436387062,
#  -0.029208678752183914,
#  0.08624880015850067,
#  0.07089538127183914,
#  -0.014765954576432705,
#  -0.0006693611503578722,
#  0.020069802179932594,
#  -0.03819115459918976,
#  -0.00992770679295063,
#  -0.018259553238749504,
#  -0.02618526853621006,
#  -0.09318587929010391,
#  -0.02386924810707569,
#  -0.04478032886981964,
#  0.030534997582435608,
#  0.04596303403377533,
#  0.03621770069003105,
#  -0.04057648777961731,
#  0.04016117751598358,
#  -0.01786518283188343,
#  0.031980033963918686,
#  -0.008691361173987389,
#  0.009503539651632309,
#  -0.019042611122131348,
#  0.003067068289965391,
#  0.026485759764909744,
#  0.03229178860783577,
#  -0.015286200679838657,
#  0.02981114201247692,
#  -0.02358427830040455,
#  0.06622137129306793,
#  0.009633481502532959,
#  -0.03079713135957718,
#  -0.013263892382383347,
#  0.020334256812930107,
#  0.04214602708816528,
#  -0.022823266685009003,
#  -0.0028324886225163937,
#  -0.014558471739292145,
#  0.008268173784017563,
#  -0.029127318412065506,
#  0.09927521646022797,
#  0.07398457825183868,
#  0.008882285095751286,
#  0.026049185544252396,
#  -0.009111675433814526,
#  -0.02825911156833172,
#  -0.017996245995163918,
#  0.03115309216082096,
#  -0.08813886344432831,
#  0.07488153874874115,
#  -0.021775031462311745,
#  0.011987961828708649,
#  -0.026276223361492157,
#  0.08399408310651779,
#  0.08171244710683823,
#  0.06066441535949707,
#  -0.0764339417219162,
#  0.044143855571746826,
#  0.02112085372209549,
#  -0.011833030730485916,
#  0.0867692083120346,
#  0.006665415596216917,
#  0.06866873055696487,
#  0.007239312399178743,
#  0.048503048717975616,
#  -0.042646970599889755,
#  -0.003639304544776678,
#  0.01406135968863964,
#  -0.0029194247908890247,
#  0.026866188272833824,
#  0.05235220119357109,
#  0.03937441110610962,
#  0.03287849202752113,
#  0.020761532709002495,
#  0.013971862383186817,
#  0.03345700353384018,
#  0.010299976915121078,
#  0.01295848935842514,
#  0.07060667872428894,
#  -0.07018036395311356,
#  0.045576177537441254,
#  0.05646047741174698,
#  0.0020586708560585976,
#  0.043722137808799744,
#  0.06340302526950836,
#  0.011341911740601063,
#  0.009918110445141792,
#  -0.010075770318508148,
#  -0.025509441271424294,
#  -0.008373166434466839,
#  -0.02583772875368595,
#  0.001136269886046648,
#  -0.0589897520840168,
#  0.004745641723275185,
#  -0.018435807898640633,
#  -0.017397481948137283,
#  0.01681463234126568,
#  -0.06424421072006226,
#  -0.007142568938434124,
#  3.457391358097084e-05,
#  -0.039726078510284424,
#  -0.00930478423833847,
#  0.015698296949267387,
#  0.056842975318431854,
#  0.0054605999030172825,
#  -0.04717521741986275,
#  0.007485869340598583,
#  -0.04701049253344536,
#  -0.06260470300912857,
#  -0.04718102142214775,
#  -0.016094837337732315,
#  0.03716633841395378,
#  0.04680677875876427,
#  0.05512678623199463,
#  0.0436321459710598,
#  0.008347750641405582,
#  -0.050426267087459564,
#  -0.04800264537334442,
#  -0.022850919514894485,
#  0.035210020840168,
#  -0.01774636283516884,
#  -0.02373032458126545,
#  -0.029801608994603157,
#  0.05359930172562599,
#  -0.010615344159305096,
#  -0.023066191002726555,
#  0.025458574295043945,
#  0.004974158946424723,
#  -0.001014155219309032,
#  -0.06077374890446663,
#  0.008248110301792622,
#  -0.037425968796014786,
#  -0.010503493249416351,
#  0.02773280441761017,
#  -0.005266204476356506,
#  -0.03517838194966316,
#  0.11502331495285034,
#  0.004405223298817873,
#  0.03129284456372261,
#  -0.044693998992443085,
#  0.07425893098115921,
#  0.00403590640053153,
#  0.02739126607775688,
#  0.062383659183979034,
#  0.10118284821510315,
#  0.014062696136534214,
#  -0.00020736525766551495,
#  0.02220970205962658,
#  -0.08649542927742004,
#  -0.025822924450039864,
#  0.04183928668498993,
#  0.0016264659352600574,
#  0.007166450377553701,
#  0.07031398266553879,
#  -0.08662224560976028,
#  0.0020863832905888557,
#  -0.03760699927806854,
#  0.027729500085115433,
#  -0.05429067090153694,
#  -0.059520173817873,
#  0.014223400503396988,
#  -0.028372474014759064,
#  -0.016118941828608513,
#  -0.020232615992426872,
#  0.050177767872810364,
#  0.05188417434692383,
#  -0.01863706298172474,
#  0.03860052302479744,
#  -0.030346771702170372,
#  -0.05496233329176903,
#  -0.0552312470972538,
#  -0.05167007073760033,
#  0.006764180492609739,
#  0.005782378371804953,
#  0.09351348876953125,
#  -0.004036187194287777,
#  -0.049820877611637115,
#  -0.01783735677599907,
#  -0.03794480860233307,
#  -0.003278070595115423,
#  -0.054998110979795456,
#  0.024662313982844353,
#  0.004259975161403418,
#  0.016541920602321625,
#  0.002698295982554555,
#  -0.10061001777648926,
#  0.03626435995101929,
#  0.037332307547330856,
#  0.04319251328706741,
#  -0.011019699275493622,
#  0.08209706842899323,
#  0.021390840411186218,
#  0.04428475722670555,
#  0.04188000038266182,
#  -0.051935773342847824,
#  -0.002975963521748781,
#  0.05979044735431671,
#  0.0742548406124115,
#  -0.0020150139462202787,
#  0.02692544460296631,
#  0.006064912769943476,
#  -0.04844086617231369,
#  0.0017839439678937197,
#  0.00030758720822632313,
#  0.040458496659994125,
#  0.04435965046286583,
#  -0.03563074767589569,
#  -0.03976408764719963,
#  0.027925236150622368,
#  0.082684226334095,
#  -0.07965248078107834,
#  0.015875760465860367,
#  0.03279569372534752,
#  -0.03166928142309189,
#  -0.021984945982694626,
#  -0.03591160476207733,
#  -0.08883149921894073,
#  0.02294500358402729,
#  0.019112013280391693,
#  0.01388715673238039,
#  0.0390804223716259,
#  -0.054033178836107254,
#  0.04915594309568405,
#  0.06972998380661011,
#  -0.03211075812578201,
#  -0.0097390441223979,
#  0.028868544846773148,
#  -0.0033424829598516226,
#  0.08983036130666733,
#  0.03087887167930603,
#  0.03523557633161545,
#  0.019423404708504677,
#  0.017946500331163406,
#  -0.06451886147260666,
#  -0.0037718010134994984,
#  0.1261759102344513,
#  -0.011137419380247593,
#  0.012733349576592445,
#  0.10529309511184692,
#  0.04819589480757713,
#  0.033995259553194046,
#  0.06185018643736839,
#  -0.04129413142800331,
#  -0.01867513731122017,
#  -0.0636071190237999,
#  0.05335525423288345,
#  0.027626728639006615,
#  -0.1079941913485527,
#  -0.08897605538368225,
#  -0.017158718779683113,
#  0.028736824169754982,
#  -0.017111392691731453,
#  0.015104650519788265,
#  0.10020733624696732,
#  0.0014172582887113094,
#  0.009903478436172009,
#  0.03387797623872757,
#  0.02802727185189724,
#  -0.1668742448091507,
#  -0.034253209829330444,
#  -0.0231300238519907,
#  0.052065569907426834,
#  0.03178756684064865,
#  0.06397078931331635,
#  -0.0016402029432356358,
#  -0.016595283523201942,
#  0.057008977979421616,
#  0.004625762812793255,
#  -0.011865700595080853,
#  0.011828549206256866,
#  -0.044640589505434036,
#  0.012250225059688091,
#  -0.045659322291612625,
#  0.00012225146929267794,
#  -0.050145287066698074,
#  -0.014018230140209198,
#  0.03174874931573868,
#  -0.007014006841927767,
#  0.015026761218905449,
#  0.04476018249988556,
#  0.023774975910782814,
#  -0.005439684260636568,
#  0.02536795474588871,
#  -0.01735799014568329,
#  -0.05899491906166077,
#  -0.04131193459033966,
#  0.002949660876765847,
#  -0.022686267271637917,
#  -0.058055926114320755,
#  -0.07144895195960999,
#  -0.041849732398986816,
#  -0.004391438793390989,
#  -0.01731567084789276,
#  0.13308382034301758,
#  -0.027040619403123856,
#  -0.04086928814649582,
#  0.007291023153811693,
#  -0.03969641402363777,
#  -0.002047858666628599,
#  -0.056368522346019745,
#  -0.011230774223804474,
#  -0.01786760613322258,
#  0.049394089728593826,
#  0.08532857894897461,
#  -0.08679153770208359,
#  -0.035554975271224976,
#  0.008265417069196701,
#  0.024181609973311424,
#  0.03299420326948166,
#  0.05771677941083908,
#  -0.07197512686252594,
#  0.05180388316512108,
#  0.0019197608344256878,
#  0.0210682675242424,
#  -0.007822208106517792,
#  0.06211327761411667,
#  -0.024579891934990883,
#  -0.00014919137174729258,
#  0.0158944521099329,
#  0.02716638334095478,
#  -0.02883896231651306,
#  -0.055349912494421005,
#  0.020200887694954872,
#  0.019287366420030594,
#  0.0792165994644165,
#  0.023010140284895897,
#  0.03034883551299572,
#  -0.024678219109773636,
#  0.014658112078905106,
#  0.028001615777611732,
#  0.03971100598573685,
#  0.0252895075827837,
#  -0.032439224421978,
#  0.07444843649864197,
#  -0.11925449222326279,
#  0.03295205906033516,
#  -0.0034096206072717905,
#  0.044828787446022034,
#  0.00887722335755825,
#  -0.015711842104792595,
#  -0.03139697387814522,
#  0.00855537410825491,
#  -0.0063006398268043995,
#  0.0035586636513471603,
#  0.08585874736309052,
#  -0.009588059037923813,
#  0.011093180626630783,
#  -0.044370364397764206,
#  -0.05001189559698105,
#  -0.00032628761255182326,
#  0.041411131620407104,
#  0.07426095753908157,
#  0.036625396460294724,
#  -0.03299779072403908,
#  -0.010097417049109936,
#  -0.08941635489463806,
#  0.044358812272548676,
#  -0.022505326196551323,
#  -0.042227067053318024,
#  -0.012438143603503704,
#  0.04719466716051102,
#  -0.02389509044587612,
#  0.029292987659573555,
#  0.04372800141572952,
#  0.00253590801730752,
#  0.0007451025885529816,
#  -0.09087300300598145,
#  -0.03994070366024971,
#  0.0113252317532897,
#  -0.06586294621229172,
#  0.048445094376802444,
#  -0.09408801048994064,
#  -0.06821048259735107,
#  -0.056750521063804626,
#  0.06644564867019653,
#  -0.11346298456192017,
#  0.0037686536088585854,
#  0.045659322291612625,
#  0.03712787851691246,
#  0.07172345370054245,
#  0.06927851587533951,
#  -0.03820768743753433,
#  -0.07167207449674606,
#  0.07856442779302597,
#  0.04026918113231659,
#  0.016496559605002403,
#  0.022915178909897804,
#  0.034035954624414444,
#  0.005578190088272095,
#  0.056497421115636826,
#  0.08866110444068909,
#  -0.03475840762257576,
#  0.02875717729330063,
#  0.027066748589277267,
#  -0.0318666510283947,
#  0.007302328012883663,
#  0.005739699583500624,
#  -0.03220710530877113,
#  -0.021580027416348457,
#  -0.01443797443062067,
#  0.035280387848615646,
#  -0.020695630460977554,
#  -0.025338558480143547,
#  0.08022528886795044,
#  0.018145989626646042,
#  -0.015265676192939281,
#  -0.024827204644680023,
#  0.05998265743255615,
#  0.03435894846916199,
#  -0.013266295194625854,
#  0.04520950838923454,
#  0.04384806379675865,
#  -0.034769583493471146,
#  -0.012541109696030617,
#  0.1093691885471344,
#  0.009679541923105717,
#  -0.008138314820826054,
#  0.02446797303855419,
#  0.006580364424735308,
#  0.009856563061475754,
#  -0.03252887725830078]

# %%
umap_embeddings = umap_3d.fit_transform(list_embeddings)

# %%
subsampled_fig_3d = px.scatter_3d(
    umap_embeddings, x=0, y=1, z=2,
    color=index_df.genre.to_list(), labels={'color': 'genre'}
)

subsampled_fig_3d.update_traces(marker_size=2)
subsampled_fig_3d.show()
# Out:
# <div>                            <div id="6562f115-9bb2-43d7-b7fb-101f9c8e367b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6562f115-9bb2-43d7-b7fb-101f9c8e367b")) {                    Plotly.newPlot(                        "6562f115-9bb2-43d7-b7fb-101f9c8e367b",                        [{"hovertemplate":"genre=['Animation']<br>0=%{x}<br>1=%{y}<br>2=%{z}<extra></extra>","legendgroup":"['Animation']","marker":{"color":"#636efa","symbol":"circle","size":2},"mode":"markers","name":"['Animation']","scene":"scene","showlegend":true,"x":[1.2412792444229126,0.9427473545074463,1.2148243188858032,0.9161466360092163,1.5455034971237183,1.2069498300552368,0.7520655989646912,0.9092527031898499,0.5506649017333984,0.8532155156135559,1.6783747673034668,1.449800729751587,0.8710481524467468,0.5398380160331726,0.828036367893219,0.869008481502533,0.7494296431541443,1.287373661994934,0.8626294136047363,1.1965899467468262,1.1910661458969116,0.7644737958908081,0.7668758034706116,4.726648330688477,0.5276853442192078,1.2047826051712036,0.8014931082725525,1.1368893384933472,0.9357113838195801,0.4544152617454529,0.5336886048316956,1.0016855001449585,0.4577794075012207,1.141577959060669,0.6179463863372803,1.3368406295776367,0.7985847592353821,1.147411584854126,0.8124212026596069,1.182814121246338,1.5656250715255737,1.0145961046218872,0.7537611722946167,1.4264544248580933,1.4732401371002197,0.4630144238471985,1.4496794939041138,0.9241188168525696,0.6386828422546387,1.0168373584747314,0.37193748354911804,6.634911060333252,1.3903987407684326,0.4071749150753021,0.7261977791786194,1.5599989891052246,0.4829596281051636,1.6948058605194092,1.416461706161499,1.081897258758545,0.794869065284729,0.9599040746688843,1.0902719497680664,0.5475075244903564,0.5640481114387512,1.2981678247451782,0.6557092070579529,0.8971452713012695,0.8846372365951538,1.1236445903778076,0.8617867231369019,0.4567759037017822,1.194901704788208,1.4285250902175903,1.3154680728912354,1.1696654558181763,0.6613556146621704,1.4208027124404907,6.787688255310059,1.3888310194015503,1.447020411491394,5.640590190887451,1.097881555557251,1.2160954475402832,1.3221070766448975,0.34937289357185364,1.4913727045059204,1.3457800149917603,1.346558928489685,1.3310703039169312,1.060235857963562,6.717525005340576,1.1691617965698242,1.2214967012405396,0.4968273937702179,1.0617928504943848,4.249475955963135,0.578109622001648,1.287741780281067,0.879030704498291,0.6263620257377625,1.3243046998977661,1.2252166271209717,0.8884046077728271,1.0710318088531494,1.479673981666565,1.329481601715088,0.717476487159729,0.6585474014282227,1.2615280151367188,1.2176014184951782,0.7909164428710938,0.9339720606803894,0.412524551153183,1.0908879041671753,1.5022372007369995,1.4649728536605835,0.7532146573066711,1.2585197687149048,1.1232211589813232,0.7820132374763489,1.379012107849121,0.8567720055580139,6.211851596832275,0.8203163146972656,0.7922638058662415,0.932487964630127,1.0462905168533325,1.3222285509109497,1.312644362449646,0.34884291887283325,0.7266762256622314,1.0228816270828247,1.4368815422058105,0.7699156999588013,6.633909702301025,1.0455561876296997,0.6993367075920105,0.9817777276039124,0.5149301290512085,1.0987409353256226,1.04692804813385,0.812037467956543,1.004366159439087,0.5803571939468384,0.6438379287719727,0.3748380243778229,1.0460654497146606,0.6027696132659912,1.0477832555770874,1.0609147548675537,1.4038679599761963,0.6955937743186951,0.6920815110206604,0.820833683013916,1.2719532251358032,0.8303629159927368,0.6574634313583374,1.147213101387024,1.266728162765503,5.675658226013184,1.2733782529830933,1.3894935846328735,1.0341126918792725,0.38562583923339844,4.500034332275391,4.111403942108154,1.286056637763977,1.26337468624115,1.459692358970642,1.28167724609375,1.01683723926544 ...

# %% [markdown]
# # Calculating Recall@K

# %%
data = pd.read_csv(os.path.join(dir_path, "data", "raw_data.csv"), lineterminator='\n', index_col=0)

# %%
literal_eval(data.iloc[0]["genres"])
# Out:
# ['Animation', 'Adventure', 'Family', 'Fantasy', 'Comedy']

# %%
embedding_size = 512
annoy_index_file = 'annoy_index.ann'

# %%
loaded_annoy_index = AnnoyIndex(embedding_size, 'euclidean')
loaded_annoy_index.load(annoy_index_file)
# Out:
# True

# %%
index_df
# Out:
#                     genre                       image_name
# 0           ['Animation']  qNBAXBIQlnOThrVvA6mA2B5ggV6.jpg
# 1               ['Drama']  vJU3rXSP9hwUuLeq8IpfsJShLOk.jpg
# 2     ['Science Fiction']  t6HIqrRAclMCA60NsSmeqe9RmNV.jpg
# 3           ['Animation']   qVdrYN8qu7xUtsdEFeGiIVIaYd.jpg
# 4              ['Comedy']  swzMoIVn6xjB857ziYJ8KBV440g.jpg
# ...                   ...                              ...
# 9734           ['Comedy']  vkF8VLrazGtk9OjdEhihG6kKAhP.jpg
# 9735         ['Thriller']  yw8x2i3vaHZZzpvqvF75E8q2N6M.jpg
# 9736            ['Drama']  bFOmE3zCFU01TuomOOwClAWdvOD.jpg
# 9737           ['Action']  kziBJGQFo9f0Vkj9s37qI0G9I0I.jpg
# 9738        ['Animation']  tn65LMkjjFFRdhwV2eSFH3WRlwA.jpg
#
# [9739 rows x 2 columns]

# %%
k_neighbors = [1, 2, 3, 5, 8]

# %%
genres_dict = {}

# %%
genres_list = [
 'Action',
 'Adventure',
 'Animation',
 'Comedy',
 'Crime',
 'Documentary',
 'Drama',
 'Family',
 'Fantasy',
 'History',
 'Horror',
 'Music',
 'Mystery',
 'Romance',
 'Science Fiction',
 'TV Movie',
 'Thriller',
 'War',
 'Western'
]

# %%
for genre in reversed(genres_list):
    print(f"Genre: {genre}")
    genres_dict[genre] = []

    genre_df = index_df[index_df["genre"] == f"['{genre}']"]

    nearest_neighbors = []
    for i, row in tqdm.tqdm(genre_df.iterrows()):
        image = load_image_arrary(row["image_name"])
        query_embedding = extract_embedding(model, image)
        nearest_indices = loaded_annoy_index.get_nns_by_vector(query_embedding, max(k_neighbors), search_k=100)
        nearest_neighbors.append(nearest_indices)


    total_queries = len(genre_df)
    for k in k_neighbors:
        correct_retrievals = 0
        genre_hits = 0
        for i in nearest_neighbors:
            indices = i[:k]            
            all_genres = []
            for neighbor in indices:
                image_neighbor = index_df.iloc[neighbor]["image_name"]
                nearest_genres = literal_eval(data[data["poster_path"] == image_neighbor]["genres"].values[0])
                all_genres += nearest_genres
            counter = Counter(all_genres)
            most_common_val = counter.most_common()[0][1]
            if counter.get(genre) == most_common_val:
                correct_retrievals += 1

            if counter.get(genre, 0) > 0:
                genre_hits += 1

        majority = correct_retrievals / total_queries
        recall = genre_hits / total_queries
        print(f"{genre} Majority Vote@{k} - {majority}")
        print(f"{genre} Recall@{k} - {recall}")
        genres_dict[genre].append({f"majority@{k}": majority})
        genres_dict[genre].append({f"recall@{k}": recall})
# Out:
# Genre: Western
# 78it [00:08,  9.56it/s]
# Western Majority Vote@1 - 0.9743589743589743
# Western Recall@1 - 0.9743589743589743
# Western Majority Vote@2 - 0.9615384615384616
# Western Recall@2 - 0.9743589743589743
# Western Majority Vote@3 - 0.8717948717948718
# Western Recall@3 - 0.9743589743589743
# Western Majority Vote@5 - 0.8589743589743589
# Western Recall@5 - 0.9743589743589743
# Western Majority Vote@8 - 0.8333333333333334
# Western Recall@8 - 0.9743589743589743
# Genre: War
# 80it [00:08,  8.92it/s]
# War Majority Vote@1 - 0.9375
# War Recall@1 - 0.9375
# War Majority Vote@2 - 0.8125
# War Recall@2 - 0.9375
# War Majority Vote@3 - 0.7375
# War Recall@3 - 0.9375
# War Majority Vote@5 - 0.75
# War Recall@5 - 0.95
# War Majority Vote@8 - 0.7375
# War Recall@8 - 0.95
# Genre: Thriller
# 575it [01:02,  9.23it/s]
# Thriller Majority Vote@1 - 0.9878260869565217
# Thriller Recall@1 - 0.9878260869565217
# Thriller Majority Vote@2 - 0.92
# Thriller Recall@2 - 0.9947826086956522
# Thriller Majority Vote@3 - 0.8678260869565217
# Thriller Recall@3 - 0.9982608695652174
# Thriller Majority Vote@5 - 0.8173913043478261
# Thriller Recall@5 - 0.9982608695652174
# Thriller Majority Vote@8 - 0.7895652173913044
# Thriller Recall@8 - 0.9982608695652174
# Genre: TV Movie
# 30it [00:03,  8.46it/s]
# TV Movie Majority Vote@1 - 0.9666666666666667
# TV Movie Recall@1 - 0.9666666666666667
# TV Movie Majority Vote@2 - 0.7666666666666667
# TV Movie Recall@2 - 0.9666666666666667
# TV Movie Majority Vote@3 - 0.6666666666666666
# TV Movie Recall@3 - 0.9666666666666667
# TV Movie Majority Vote@5 - 0.43333333333333335
# TV Movie Recall@5 - 0.9666666666666667
# TV Movie Majority Vote@8 - 0.43333333333333335
# TV Movie Recall@8 - 0.9666666666666667
# Genre: Science Fiction
# 303it [00:34,  8.73it/s]
# Science Fiction Majority Vote@1 - 0.9867986798679867
# Science Fiction Recall@1 - 0.9867986798679867
# Science Fiction Majority Vote@2 - 0.8976897689768977
# Science Fiction Recall@2 - 0.9900990099009901
# Science Fiction Majority Vote@3 - 0.8415841584158416
# Science Fiction Recall@3 - 0.9900990099009901
# Science Fiction Majority Vote@5 - 0.8118811881188119
# Science Fiction Recall@5 - 0.9900990099009901
# Science Fiction Majority Vote@8 - 0.7953795379537953
# Science Fiction Recall@8 - 0.9966996699669967
# Genre: Romance
# 378it [00:35, 10.52it/s]
# Romance Majority Vote@1 - 0.9920634920634921
# Romance Recall@1 - 0.9920634920634921
# Romance Majority Vote@2 - 0.91005291005291
# Romance Recall@2 - 0.9947089947089947
# Romance Majority Vote@3 - 0.8756613756613757
# Romance Recall@3 - 0.9973544973544973
# Romance Majority Vote@5 - 0.8597883597883598
# Romance Recall@5 - 0.9973544973544973
# Romance Majority Vote@8 - 0.8386243386243386
# Romance Recall@8 - 0.9973544973544973
# Genre: Mystery
# 109it [00:10, 10.48it/s]
# Mystery Majority Vote@1 - 0.9908256880733946
# Mystery Recall@1 - 0.9908256880733946
# Mystery Majority Vote@2 - 0.9174311926605505
# Mystery Recall@2 - 0.9908256880733946
# Mystery Majority Vote@3 - 0.8715596330275229
# Mystery Recall@3 - 0.9908256880733946
# Mystery Majority Vote@5 - 0.8165137614678899
# Mystery Recall@5 - 0.9908256880733946
# Mystery Majority Vote@8 - 0.8348623853211009
# Mystery Recall@8 - 0.9908256880733946
# Genre: Music
# 72it [00:07,  9.65it/s]
# Music Majority Vote@1 - 0.9861111111111112
# Music Recall@1 - 0.9861111111111112
# Music Majority Vote@2 - 0.9305555555555556
# Music Recall@2 - 0.9861111111111112
# Music Majority Vote@3 - 0.8472222222222222
# Music Recall@3 - 0.9861111111111112
# Music Majority Vote@5 - 0.8333333333333334
# Music Recall@5 - 1.0
# Music Majority Vote@8 - 0.8194444444444444
# Music Recall@8 - 1.0
# Genre: Horror
# 906it [01:44,  8.69it/s]
# Horror Majority Vote@1 - 0.9922737306843267
# Horror Recall@1 - 0.9922737306843267
# Horror Majority Vote@2 - 0.9260485651214128
# Horror Recall@2 - 0.9977924944812362
# Horror Majority Vote@3 - 0.8664459161147903
# Horror Recall@3 - 0.9988962472406181
# Horror Majority Vote@5 - 0.8465783664459161
# Horror Recall@5 - 0.9988962472406181
# Horror Majority Vote@8 - 0.8333333333333334
# Horror Recall@8 - 0.9988962472406181
# Genre: History
# 38it [00:04,  9.38it/s]
# History Majority Vote@1 - 0.9210526315789473
# History Recall@1 - 0.9210526315789473
# History Majority Vote@2 - 0.8947368421052632
# History Recall@2 - 0.9473684210526315
# History Majority Vote@3 - 0.8157894736842105
# History Recall@3 - 0.9473684210526315
# History Majority Vote@5 - 0.6578947368421053
# History Recall@5 - 0.9736842105263158
# History Majority Vote@8 - 0.5
# History Recall@8 - 0.9736842105263158
# Genre: Fantasy
# 251it [00:28,  8.82it/s]
# Fantasy Majority Vote@1 - 1.0
# Fantasy Recall@1 - 1.0
# Fantasy Majority Vote@2 - 0.9043824701195219
# Fantasy Recall@2 - 1.0
# Fantasy Majority Vote@3 - 0.8247011952191236
# Fantasy Recall@3 - 1.0
# Fantasy Majority Vote@5 - 0.8087649402390438
# Fantasy Recall@5 - 1.0
# Fantasy Majority Vote@8 - 0.8007968127490039
# Fantasy Recall@8 - 1.0
# Genre: Family
# 320it [00:32,  9.77it/s]
# Family Majority Vote@1 - 0.9875
# Family Recall@1 - 0.9875
# Family Majority Vote@2 - 0.915625
# Family Recall@2 - 0.990625
# Family Majority Vote@3 - 0.865625
# Family Recall@3 - 0.99375
# Family Majority Vote@5 - 0.8375
# Family Recall@5 - 0.99375
# Family Majority Vote@8 - 0.8
# Family Recall@8 - 0.996875
# Genre: Drama
# 1805it [02:52, 10.48it/s]
# Drama Majority Vote@1 - 0.971191135734072
# Drama Recall@1 - 0.971191135734072
# Drama Majority Vote@2 - 0.8614958448753463
# Drama Recall@2 - 0.9850415512465374
# Drama Majority Vote@3 - 0.7817174515235457
# Drama Recall@3 - 0.9939058171745152
# Drama Majority Vote@5 - 0.7257617728531855
# Drama Recall@5 - 0.997229916897507
# Drama Majority Vote@8 - 0.6958448753462604
# Drama Recall@8 - 0.9988919667590028
# Genre: Documentary
# 142it [00:13, 10.33it/s]
# Documentary Majority Vote@1 - 0.9788732394366197
# Documentary Recall@1 - 0.9788732394366197
# Documentary Majority Vote@2 - 0.9647887323943662
# Documentary Recall@2 - 0.9788732394366197
# Documentary Majority Vote@3 - 0.8028169014084507
# Documentary Recall@3 - 0.9788732394366197
# Documentary Majority Vote@5 - 0.7605633802816901
# Documentary Recall@5 - 0.9788732394366197
# Documentary Majority Vote@8 - 0.7676056338028169
# Documentary Recall@8 - 0.9788732394366197
# Genre: Crime
# 360it [00:36,  9.88it/s]
# Crime Majority Vote@1 - 0.9638888888888889
# Crime Recall@1 - 0.9638888888888889
# Crime Majority Vote@2 - 0.8527777777777777
# Crime Recall@2 - 0.9694444444444444
# Crime Majority Vote@3 - 0.7777777777777778
# Crime Recall@3 - 0.975
# Crime Majority Vote@5 - 0.7138888888888889
# Crime Recall@5 - 0.9916666666666667
# Crime Majority Vote@8 - 0.6916666666666667
# Crime Recall@8 - 0.9916666666666667
# Genre: Comedy
# 1333it [02:08, 10.39it/s]
# Comedy Majority Vote@1 - 0.981245311327832
# Comedy Recall@1 - 0.981245311327832
# Comedy Majority Vote@2 - 0.9099774943735934
# Comedy Recall@2 - 0.9902475618904726
# Comedy Majority Vote@3 - 0.8769692423105776
# Comedy Recall@3 - 0.9954988747186797
# Comedy Majority Vote@5 - 0.8424606151537885
# Comedy Recall@5 - 0.9969992498124531
# Comedy Majority Vote@8 - 0.8304576144036009
# Comedy Recall@8 - 0.9992498124531133
# Genre: Animation
# 864it [01:26, 10.05it/s]
# Animation Majority Vote@1 - 0.9942129629629629
# Animation Recall@1 - 0.9942129629629629
# Animation Majority Vote@2 - 0.9560185185185185
# Animation Recall@2 - 0.9965277777777778
# Animation Majority Vote@3 - 0.9398148148148148
# Animation Recall@3 - 0.9965277777777778
# Animation Majority Vote@5 - 0.9282407407407407
# Animation Recall@5 - 0.9976851851851852
# Animation Majority Vote@8 - 0.9247685185185185
# Animation Recall@8 - 0.9988425925925926
# Genre: Adventure
# 542it [00:56,  9.59it/s]
# Adventure Majority Vote@1 - 0.985239852398524
# Adventure Recall@1 - 0.985239852398524
# Adventure Majority Vote@2 - 0.8505535055350554
# Adventure Recall@2 - 0.9907749077490775
# Adventure Majority Vote@3 - 0.8099630996309963
# Adventure Recall@3 - 0.996309963099631
# Adventure Majority Vote@5 - 0.7619926199261993
# Adventure Recall@5 - 0.996309963099631
# Adventure Majority Vote@8 - 0.7509225092250923
# Adventure Recall@8 - 0.996309963099631
# Genre: Action
# 1553it [02:37,  9.88it/s]
# Action Majority Vote@1 - 0.9665164198325821
# Action Recall@1 - 0.9665164198325821
# Action Majority Vote@2 - 0.8074694140373471
# Action Recall@2 - 0.9800386349001932
# Action Majority Vote@3 - 0.7231165486155827
# Action Recall@3 - 0.9877656149388281
# Action Majority Vote@5 - 0.6754668383773342
# Action Recall@5 - 0.9935608499678042
# Action Majority Vote@8 - 0.6452028332260141
# Action Recall@8 - 0.9974243399871217

# %%
pd.DataFrame.from_dict(genres_dict, orient="index")
# Out:
#                                                   0
# Western          {'majority@1': 0.9743589743589743}  \
# War                          {'majority@1': 0.9375}
# Thriller         {'majority@1': 0.9878260869565217}
# TV Movie         {'majority@1': 0.9666666666666667}
# Science Fiction  {'majority@1': 0.9867986798679867}
# Romance          {'majority@1': 0.9920634920634921}
# Mystery          {'majority@1': 0.9908256880733946}
# Music            {'majority@1': 0.9861111111111112}
# Horror           {'majority@1': 0.9922737306843267}
# History          {'majority@1': 0.9210526315789473}
# Fantasy                         {'majority@1': 1.0}
# Family                       {'majority@1': 0.9875}
# Drama             {'majority@1': 0.971191135734072}
# Documentary      {'majority@1': 0.9788732394366197}
# Crime            {'majority@1': 0.9638888888888889}
# Comedy            {'majority@1': 0.981245311327832}
# Animation        {'majority@1': 0.9942129629629629}
# Adventure         {'majority@1': 0.985239852398524}
# Action           {'majority@1': 0.9665164198325821}
#
#                                                 1
# Western          {'recall@1': 0.9743589743589743}  \
# War                          {'recall@1': 0.9375}
# Thriller         {'recall@1': 0.9878260869565217}
# TV Movie         {'recall@1': 0.9666666666666667}
# Science Fiction  {'recall@1': 0.9867986798679867}
# Romance          {'recall@1': 0.9920634920634921}
# Mystery          {'recall@1': 0.9908256880733946}
# Music            {'recall@1': 0.9861111111111112}
# Horror           {'recall@1': 0.9922737306843267}
# History          {'recall@1': 0.9210526315789473}
# Fantasy                         {'recall@1': 1.0}
# Family                       {'recall@1': 0.9875}
# Drama             {'recall@1': 0.971191135734072}
# Documentary      {'recall@1': 0.9788732394366197}
# Crime            {'recall@1': 0.9638888888888889}
# Comedy            {'recall@1': 0.981245311327832}
# Animation        {'recall@1': 0.9942129629629629}
# Adventure         {'recall@1': 0.985239852398524}
# Action           {'recall@1': 0.9665164198325821}
#
#                                                   2
# Western          {'majority@2': 0.9615384615384616}  \
# War                          {'majority@2': 0.8125}
# Thriller                       {'majority@2': 0.92}
# TV Movie         {'majority@2': 0.7666666666666667}
# Science Fiction  {'majority@2': 0.8976897689768977}
# Romance            {'majority@2': 0.91005291005291}
# Mystery          {'majority@2': 0.9174311926605505}
# Music            {'majority@2': 0.9305555555555556}
# Horror           {'majority@2': 0.9260485651214128}
# History          {'majority@2': 0.8947368421052632}
# Fantasy          {'majority@2': 0.9043824701195219}
# Family                     {'majority@2': 0.915625}
# Drama            {'majority@2': 0.8614958448753463}
# Documentary      {'majority@2': 0.9647887323943662}
# Crime            {'majority@2': 0.8527777777777777}
# Comedy           {'majority@2': 0.9099774943735934}
# Animation        {'majority@2': 0.9560185185185185}
# Adventure        {'majority@2': 0.8505535055350554}
# Action           {'majority@2': 0.8074694140373471}
#
#                                                 3
# Western          {'recall@2': 0.9743589743589743}  \
# War                          {'recall@2': 0.9375}
# Thriller         {'recall@2': 0.9947826086956522}
# TV Movie         {'recall@2': 0.9666666666666667}
# Science Fiction  {'recall@2': 0.9900990099009901}
# Romance          {'recall@2': 0.9947089947089947}
# Mystery          {'recall@2': 0.9908256880733946}
# Music            {'recall@2': 0.9861111111111112}
# Horror           {'recall@2': 0.9977924944812362}
# History          {'recall@2': 0.9473684210526315}
# Fantasy                         {'recall@2': 1.0}
# Family                     {'recall@2': 0.990625}
# Drama            {'recall@2': 0.9850415512465374}
# Documentary      {'recall@2': 0.9788732394366197}
# Crime            {'recall@2': 0.9694444444444444}
# Comedy           {'recall@2': 0.9902475618904726}
# Animation        {'recall@2': 0.9965277777777778}
# Adventure        {'recall@2': 0.9907749077490775}
# Action           {'recall@2': 0.9800386349001932}
#
#                                                   4
# Western          {'majority@3': 0.8717948717948718}  \
# War                          {'majority@3': 0.7375}
# Thriller         {'majority@3': 0.8678260869565217}
# TV Movie         {'majority@3': 0.6666666666666666}
# Science Fiction  {'majority@3': 0.8415841584158416}
# Romance          {'majority@3': 0.8756613756613757}
# Mystery          {'majority@3': 0.8715596330275229}
# Music            {'majority@3': 0.8472222222222222}
# Horror           {'majority@3': 0.8664459161147903}
# History          {'majority@3': 0.8157894736842105}
# Fantasy          {'majority@3': 0.8247011952191236}
# Family                     {'majority@3': 0.865625}
# Drama            {'majority@3': 0.7817174515235457}
# Documentary      {'majority@3': 0.8028169014084507}
# Crime            {'majority@3': 0.7777777777777778}
# Comedy           {'majority@3': 0.8769692423105776}
# Animation        {'majority@3': 0.9398148148148148}
# Adventure        {'majority@3': 0.8099630996309963}
# Action           {'majority@3': 0.7231165486155827}
#
#                                                 5
# Western          {'recall@3': 0.9743589743589743}  \
# War                          {'recall@3': 0.9375}
# Thriller         {'recall@3': 0.9982608695652174}
# TV Movie         {'recall@3': 0.9666666666666667}
# Science Fiction  {'recall@3': 0.9900990099009901}
# Romance          {'recall@3': 0.9973544973544973}
# Mystery          {'recall@3': 0.9908256880733946}
# Music            {'recall@3': 0.9861111111111112}
# Horror           {'recall@3': 0.9988962472406181}
# History          {'recall@3': 0.9473684210526315}
# Fantasy                         {'recall@3': 1.0}
# Family                      {'recall@3': 0.99375}
# Drama            {'recall@3': 0.9939058171745152}
# Documentary      {'recall@3': 0.9788732394366197}
# Crime                         {'recall@3': 0.975}
# Comedy           {'recall@3': 0.9954988747186797}
# Animation        {'recall@3': 0.9965277777777778}
# Adventure         {'recall@3': 0.996309963099631}
# Action           {'recall@3': 0.9877656149388281}
#
#                                                    6
# Western           {'majority@5': 0.8589743589743589}  \
# War                             {'majority@5': 0.75}
# Thriller          {'majority@5': 0.8173913043478261}
# TV Movie         {'majority@5': 0.43333333333333335}
# Science Fiction   {'majority@5': 0.8118811881188119}
# Romance           {'majority@5': 0.8597883597883598}
# Mystery           {'majority@5': 0.8165137614678899}
# Music             {'majority@5': 0.8333333333333334}
# Horror            {'majority@5': 0.8465783664459161}
# History           {'majority@5': 0.6578947368421053}
# Fantasy           {'majority@5': 0.8087649402390438}
# Family                        {'majority@5': 0.8375}
# Drama             {'majority@5': 0.7257617728531855}
# Documentary       {'majority@5': 0.7605633802816901}
# Crime             {'majority@5': 0.7138888888888889}
# Comedy            {'majority@5': 0.8424606151537885}
# Animation         {'majority@5': 0.9282407407407407}
# Adventure         {'majority@5': 0.7619926199261993}
# Action            {'majority@5': 0.6754668383773342}
#
#                                                 7
# Western          {'recall@5': 0.9743589743589743}  \
# War                            {'recall@5': 0.95}
# Thriller         {'recall@5': 0.9982608695652174}
# TV Movie         {'recall@5': 0.9666666666666667}
# Science Fiction  {'recall@5': 0.9900990099009901}
# Romance          {'recall@5': 0.9973544973544973}
# Mystery          {'recall@5': 0.9908256880733946}
# Music                           {'recall@5': 1.0}
# Horror           {'recall@5': 0.9988962472406181}
# History          {'recall@5': 0.9736842105263158}
# Fantasy                         {'recall@5': 1.0}
# Family                      {'recall@5': 0.99375}
# Drama             {'recall@5': 0.997229916897507}
# Documentary      {'recall@5': 0.9788732394366197}
# Crime            {'recall@5': 0.9916666666666667}
# Comedy           {'recall@5': 0.9969992498124531}
# Animation        {'recall@5': 0.9976851851851852}
# Adventure         {'recall@5': 0.996309963099631}
# Action           {'recall@5': 0.9935608499678042}
#
#                                                    8
# Western           {'majority@8': 0.8333333333333334}  \
# War                           {'majority@8': 0.7375}
# Thriller          {'majority@8': 0.7895652173913044}
# TV Movie         {'majority@8': 0.43333333333333335}
# Science Fiction   {'majority@8': 0.7953795379537953}
# Romance           {'majority@8': 0.8386243386243386}
# Mystery           {'majority@8': 0.8348623853211009}
# Music             {'majority@8': 0.8194444444444444}
# Horror            {'majority@8': 0.8333333333333334}
# History                          {'majority@8': 0.5}
# Fantasy           {'majority@8': 0.8007968127490039}
# Family                           {'majority@8': 0.8}
# Drama             {'majority@8': 0.6958448753462604}
# Documentary       {'majority@8': 0.7676056338028169}
# Crime             {'majority@8': 0.6916666666666667}
# Comedy            {'majority@8': 0.8304576144036009}
# Animation         {'majority@8': 0.9247685185185185}
# Adventure         {'majority@8': 0.7509225092250923}
# Action            {'majority@8': 0.6452028332260141}
#
#                                                 9
# Western          {'recall@8': 0.9743589743589743}
# War                            {'recall@8': 0.95}
# Thriller         {'recall@8': 0.9982608695652174}
# TV Movie         {'recall@8': 0.9666666666666667}
# Science Fiction  {'recall@8': 0.9966996699669967}
# Romance          {'recall@8': 0.9973544973544973}
# Mystery          {'recall@8': 0.9908256880733946}
# Music                           {'recall@8': 1.0}
# Horror           {'recall@8': 0.9988962472406181}
# History          {'recall@8': 0.9736842105263158}
# Fantasy                         {'recall@8': 1.0}
# Family                     {'recall@8': 0.996875}
# Drama            {'recall@8': 0.9988919667590028}
# Documentary      {'recall@8': 0.9788732394366197}
# Crime            {'recall@8': 0.9916666666666667}
# Comedy           {'recall@8': 0.9992498124531133}
# Animation        {'recall@8': 0.9988425925925926}
# Adventure         {'recall@8': 0.996309963099631}
# Action           {'recall@8': 0.9974243399871217}

# %%
flattened_data = [
    {**entry, "index": index}
    for index, entries in genres_dict.items()
    for entry in entries
]

# %%
metrics = pd.DataFrame(flattened_data).set_index("index")

# %%
metrics = metrics.groupby(metrics.index).first()

# %%
metrics
# Out:
#                  majority@1  recall@1  majority@2  recall@2  majority@3
# index
# Action             0.966516  0.966516    0.807469  0.980039    0.723117  \
# Adventure          0.985240  0.985240    0.850554  0.990775    0.809963
# Animation          0.994213  0.994213    0.956019  0.996528    0.939815
# Comedy             0.981245  0.981245    0.909977  0.990248    0.876969
# Crime              0.963889  0.963889    0.852778  0.969444    0.777778
# Documentary        0.978873  0.978873    0.964789  0.978873    0.802817
# Drama              0.971191  0.971191    0.861496  0.985042    0.781717
# Family             0.987500  0.987500    0.915625  0.990625    0.865625
# Fantasy            1.000000  1.000000    0.904382  1.000000    0.824701
# History            0.921053  0.921053    0.894737  0.947368    0.815789
# Horror             0.992274  0.992274    0.926049  0.997792    0.866446
# Music              0.986111  0.986111    0.930556  0.986111    0.847222
# Mystery            0.990826  0.990826    0.917431  0.990826    0.871560
# Romance            0.992063  0.992063    0.910053  0.994709    0.875661
# Science Fiction    0.986799  0.986799    0.897690  0.990099    0.841584
# TV Movie           0.966667  0.966667    0.766667  0.966667    0.666667
# Thriller           0.987826  0.987826    0.920000  0.994783    0.867826
# War                0.937500  0.937500    0.812500  0.937500    0.737500
# Western            0.974359  0.974359    0.961538  0.974359    0.871795
#
#                  recall@3  majority@5  recall@5  majority@8  recall@8
# index
# Action           0.987766    0.675467  0.993561    0.645203  0.997424
# Adventure        0.996310    0.761993  0.996310    0.750923  0.996310
# Animation        0.996528    0.928241  0.997685    0.924769  0.998843
# Comedy           0.995499    0.842461  0.996999    0.830458  0.999250
# Crime            0.975000    0.713889  0.991667    0.691667  0.991667
# Documentary      0.978873    0.760563  0.978873    0.767606  0.978873
# Drama            0.993906    0.725762  0.997230    0.695845  0.998892
# Family           0.993750    0.837500  0.993750    0.800000  0.996875
# Fantasy          1.000000    0.808765  1.000000    0.800797  1.000000
# History          0.947368    0.657895  0.973684    0.500000  0.973684
# Horror           0.998896    0.846578  0.998896    0.833333  0.998896
# Music            0.986111    0.833333  1.000000    0.819444  1.000000
# Mystery          0.990826    0.816514  0.990826    0.834862  0.990826
# Romance          0.997354    0.859788  0.997354    0.838624  0.997354
# Science Fiction  0.990099    0.811881  0.990099    0.795380  0.996700
# TV Movie         0.966667    0.433333  0.966667    0.433333  0.966667
# Thriller         0.998261    0.817391  0.998261    0.789565  0.998261
# War              0.937500    0.750000  0.950000    0.737500  0.950000
# Western          0.974359    0.858974  0.974359    0.833333  0.974359

# %%
recalls = ["recall@1", "recall@2", "recall@3", "recall@5", "recall@8"]

# %%
majorities = ["majority@1", "majority@3", "majority@8"]

# %%
metrics[majorities]
# Out:
#                  majority@1  majority@3  majority@8
# index
# Action             0.966516    0.723117    0.645203
# Adventure          0.985240    0.809963    0.750923
# Animation          0.994213    0.939815    0.924769
# Comedy             0.981245    0.876969    0.830458
# Crime              0.963889    0.777778    0.691667
# Documentary        0.978873    0.802817    0.767606
# Drama              0.971191    0.781717    0.695845
# Family             0.987500    0.865625    0.800000
# Fantasy            1.000000    0.824701    0.800797
# History            0.921053    0.815789    0.500000
# Horror             0.992274    0.866446    0.833333
# Music              0.986111    0.847222    0.819444
# Mystery            0.990826    0.871560    0.834862
# Romance            0.992063    0.875661    0.838624
# Science Fiction    0.986799    0.841584    0.795380
# TV Movie           0.966667    0.666667    0.433333
# Thriller           0.987826    0.867826    0.789565
# War                0.937500    0.737500    0.737500
# Western            0.974359    0.871795    0.833333

# %%
print(metrics[majorities].to_latex(index=True, escape=False,
                                     sparsify=True,
        multirow=True,
        multicolumn=True,
        multicolumn_format='c',
        position='p',
        bold_rows=True))
# Out:
# \begin{table}[p]
# \begin{tabular}{lrrr}
# \toprule
#  & majority@1 & majority@3 & majority@8 \\
# index &  &  &  \\
# \midrule
# \textbf{Action} & 0.966516 & 0.723117 & 0.645203 \\
# \textbf{Adventure} & 0.985240 & 0.809963 & 0.750923 \\
# \textbf{Animation} & 0.994213 & 0.939815 & 0.924769 \\
# \textbf{Comedy} & 0.981245 & 0.876969 & 0.830458 \\
# \textbf{Crime} & 0.963889 & 0.777778 & 0.691667 \\
# \textbf{Documentary} & 0.978873 & 0.802817 & 0.767606 \\
# \textbf{Drama} & 0.971191 & 0.781717 & 0.695845 \\
# \textbf{Family} & 0.987500 & 0.865625 & 0.800000 \\
# \textbf{Fantasy} & 1.000000 & 0.824701 & 0.800797 \\
# \textbf{History} & 0.921053 & 0.815789 & 0.500000 \\
# \textbf{Horror} & 0.992274 & 0.866446 & 0.833333 \\
# \textbf{Music} & 0.986111 & 0.847222 & 0.819444 \\
# \textbf{Mystery} & 0.990826 & 0.871560 & 0.834862 \\
# \textbf{Romance} & 0.992063 & 0.875661 & 0.838624 \\
# \textbf{Science Fiction} & 0.986799 & 0.841584 & 0.795380 \\
# \textbf{TV Movie} & 0.966667 & 0.666667 & 0.433333 \\
# \textbf{Thriller} & 0.987826 & 0.867826 & 0.789565 \\
# \textbf{War} & 0.937500 & 0.737500 & 0.737500 \\
# \textbf{Western} & 0.974359 & 0.871795 & 0.833333 \\
# \bottomrule
# \end{tabular}
# \end{table}

# %%
fig = px.bar(metrics[majorities], x=metrics.index, y="majority@1", color=metrics.index, title="Genre Majority Vote @ 1 Neighbor")
fig.show()
# Out:
# <div>                            <div id="5b6d48fe-dd4b-4b43-979e-d80c659d333c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5b6d48fe-dd4b-4b43-979e-d80c659d333c")) {                    Plotly.newPlot(                        "5b6d48fe-dd4b-4b43-979e-d80c659d333c",                        [{"alignmentgroup":"True","hovertemplate":"index=%{x}<br>majority@1=%{y}<extra></extra>","legendgroup":"Action","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Action","offsetgroup":"Action","orientation":"v","showlegend":true,"textposition":"auto","x":["Action"],"xaxis":"x","y":[0.9665164198325821],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"index=%{x}<br>majority@1=%{y}<extra></extra>","legendgroup":"Adventure","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Adventure","offsetgroup":"Adventure","orientation":"v","showlegend":true,"textposition":"auto","x":["Adventure"],"xaxis":"x","y":[0.985239852398524],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"index=%{x}<br>majority@1=%{y}<extra></extra>","legendgroup":"Animation","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Animation","offsetgroup":"Animation","orientation":"v","showlegend":true,"textposition":"auto","x":["Animation"],"xaxis":"x","y":[0.9942129629629629],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"index=%{x}<br>majority@1=%{y}<extra></extra>","legendgroup":"Comedy","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Comedy","offsetgroup":"Comedy","orientation":"v","showlegend":true,"textposition":"auto","x":["Comedy"],"xaxis":"x","y":[0.981245311327832],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"index=%{x}<br>majority@1=%{y}<extra></extra>","legendgroup":"Crime","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"Crime","offsetgroup":"Crime","orientation":"v","showlegend":true,"textposition":"auto","x":["Crime"],"xaxis":"x","y":[0.9638888888888889],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"index=%{x}<br>majority@1=%{y}<extra></extra>","legendgroup":"Documentary","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"Documentary","offsetgroup":"Documentary","orientation":"v","showlegend":true,"textposition":"auto","x":["Documentary"],"xaxis":"x","y":[0.9788732394366197],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"index=%{x}<br>majority@1=%{y}<extra></extra>","legendgroup":"Drama","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"Drama","offsetgroup":"Drama","orientation":"v","showlegend":true,"textposition":"auto","x":["Drama"],"xaxis":"x","y":[0.971191135734072],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"index=%{x}<br>majority@1=%{y}<extra></extra>","legendgroup":"Family","marker":{"color":"#B6E880","pattern":{"shape":""}},"name":"Family","offsetgroup":"Family","orientation":"v","showlegend":true,"textposition":"auto","x":["Family"],"xaxis":"x","y":[0.9875],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"index=%{x}<br>majority@1=%{y}<extra></extra>","legendgroup":"Fantasy","marker":{"color":"#FF97FF","pattern":{"shape":""}},"name":"Fantasy","offsetgroup":"Fantasy","orientation":"v","showlegend":true,"textposition":"auto","x":["Fantasy"],"xaxis":"x","y":[1.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"index=%{x}<br>majority@1=%{y}<extra></extra>","legendgroup":"History","marker":{"color":"#FECB52","pattern":{"shape":""}},"name":"History","offsetgroup":"History","orientation":"v","showlegend":true,"textposition":"auto","x":["History"],"xaxis":"x","y":[0.9210526315789473],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"index=%{x}<br>majority@1=%{y}<ext ...

# %%
fig = px.bar(metrics[majorities], x=metrics.index, y="majority@5", color=metrics.index, title="Genre Majority Vote @ 5 Neighbors")
fig.show()
# Out:
# <div>                            <div id="db1bdae5-fc91-4421-9804-43077c0bad5e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("db1bdae5-fc91-4421-9804-43077c0bad5e")) {                    Plotly.newPlot(                        "db1bdae5-fc91-4421-9804-43077c0bad5e",                        [{"alignmentgroup":"True","hovertemplate":"index=%{x}<br>majority@5=%{y}<extra></extra>","legendgroup":"Action","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Action","offsetgroup":"Action","orientation":"v","showlegend":true,"textposition":"auto","x":["Action"],"xaxis":"x","y":[0.6754668383773342],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"index=%{x}<br>majority@5=%{y}<extra></extra>","legendgroup":"Adventure","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Adventure","offsetgroup":"Adventure","orientation":"v","showlegend":true,"textposition":"auto","x":["Adventure"],"xaxis":"x","y":[0.7619926199261993],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"index=%{x}<br>majority@5=%{y}<extra></extra>","legendgroup":"Animation","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Animation","offsetgroup":"Animation","orientation":"v","showlegend":true,"textposition":"auto","x":["Animation"],"xaxis":"x","y":[0.9282407407407407],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"index=%{x}<br>majority@5=%{y}<extra></extra>","legendgroup":"Comedy","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Comedy","offsetgroup":"Comedy","orientation":"v","showlegend":true,"textposition":"auto","x":["Comedy"],"xaxis":"x","y":[0.8424606151537885],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"index=%{x}<br>majority@5=%{y}<extra></extra>","legendgroup":"Crime","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"Crime","offsetgroup":"Crime","orientation":"v","showlegend":true,"textposition":"auto","x":["Crime"],"xaxis":"x","y":[0.7138888888888889],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"index=%{x}<br>majority@5=%{y}<extra></extra>","legendgroup":"Documentary","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"Documentary","offsetgroup":"Documentary","orientation":"v","showlegend":true,"textposition":"auto","x":["Documentary"],"xaxis":"x","y":[0.7605633802816901],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"index=%{x}<br>majority@5=%{y}<extra></extra>","legendgroup":"Drama","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"Drama","offsetgroup":"Drama","orientation":"v","showlegend":true,"textposition":"auto","x":["Drama"],"xaxis":"x","y":[0.7257617728531855],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"index=%{x}<br>majority@5=%{y}<extra></extra>","legendgroup":"Family","marker":{"color":"#B6E880","pattern":{"shape":""}},"name":"Family","offsetgroup":"Family","orientation":"v","showlegend":true,"textposition":"auto","x":["Family"],"xaxis":"x","y":[0.8375],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"index=%{x}<br>majority@5=%{y}<extra></extra>","legendgroup":"Fantasy","marker":{"color":"#FF97FF","pattern":{"shape":""}},"name":"Fantasy","offsetgroup":"Fantasy","orientation":"v","showlegend":true,"textposition":"auto","x":["Fantasy"],"xaxis":"x","y":[0.8087649402390438],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"index=%{x}<br>majority@5=%{y}<extra></extra>","legendgroup":"History","marker":{"color":"#FECB52","pattern":{"shape":""}},"name":"History","offsetgroup":"History","orientation":"v","showlegend":true,"textposition":"auto","x":["History"],"xaxis":"x","y":[0.6578947368421053],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"index=%{x}<br>m ...

# %%
recalls = ["recall@1", "recall@2", "recall@3", "recall@5", "recall@8"]

# %%
print(metrics[recalls].to_latex(index=True, escape=False,
                                     sparsify=True,
        multirow=True,
        multicolumn=True,
        multicolumn_format='c',
        position='p',
        bold_rows=True))
# Out:
# \begin{table}[p]
# \begin{tabular}{lrrr}
# \toprule
#  & recall@1 & recall@3 & recall@8 \\
# index &  &  &  \\
# \midrule
# \textbf{Action} & 0.966516 & 0.987766 & 0.997424 \\
# \textbf{Adventure} & 0.985240 & 0.996310 & 0.996310 \\
# \textbf{Animation} & 0.994213 & 0.996528 & 0.998843 \\
# \textbf{Comedy} & 0.981245 & 0.995499 & 0.999250 \\
# \textbf{Crime} & 0.963889 & 0.975000 & 0.991667 \\
# \textbf{Documentary} & 0.978873 & 0.978873 & 0.978873 \\
# \textbf{Drama} & 0.971191 & 0.993906 & 0.998892 \\
# \textbf{Family} & 0.987500 & 0.993750 & 0.996875 \\
# \textbf{Fantasy} & 1.000000 & 1.000000 & 1.000000 \\
# \textbf{History} & 0.921053 & 0.947368 & 0.973684 \\
# \textbf{Horror} & 0.992274 & 0.998896 & 0.998896 \\
# \textbf{Music} & 0.986111 & 0.986111 & 1.000000 \\
# \textbf{Mystery} & 0.990826 & 0.990826 & 0.990826 \\
# \textbf{Romance} & 0.992063 & 0.997354 & 0.997354 \\
# \textbf{Science Fiction} & 0.986799 & 0.990099 & 0.996700 \\
# \textbf{TV Movie} & 0.966667 & 0.966667 & 0.966667 \\
# \textbf{Thriller} & 0.987826 & 0.998261 & 0.998261 \\
# \textbf{War} & 0.937500 & 0.937500 & 0.950000 \\
# \textbf{Western} & 0.974359 & 0.974359 & 0.974359 \\
# \bottomrule
# \end{tabular}
# \end{table}

# %%
fig = px.bar(metrics[["recall@1"]], x=metrics.index, y="recall@1", color=metrics.index, title="Recall @ 1 Neighbor")
fig.show()
# Out:
# <div>                            <div id="0071fe74-06b5-4631-82de-ecb4e78a0ec2" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0071fe74-06b5-4631-82de-ecb4e78a0ec2")) {                    Plotly.newPlot(                        "0071fe74-06b5-4631-82de-ecb4e78a0ec2",                        [{"alignmentgroup":"True","hovertemplate":"index=%{x}<br>recall@1=%{y}<extra></extra>","legendgroup":"Action","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Action","offsetgroup":"Action","orientation":"v","showlegend":true,"textposition":"auto","x":["Action"],"xaxis":"x","y":[0.9665164198325821],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"index=%{x}<br>recall@1=%{y}<extra></extra>","legendgroup":"Adventure","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Adventure","offsetgroup":"Adventure","orientation":"v","showlegend":true,"textposition":"auto","x":["Adventure"],"xaxis":"x","y":[0.985239852398524],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"index=%{x}<br>recall@1=%{y}<extra></extra>","legendgroup":"Animation","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Animation","offsetgroup":"Animation","orientation":"v","showlegend":true,"textposition":"auto","x":["Animation"],"xaxis":"x","y":[0.9942129629629629],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"index=%{x}<br>recall@1=%{y}<extra></extra>","legendgroup":"Comedy","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Comedy","offsetgroup":"Comedy","orientation":"v","showlegend":true,"textposition":"auto","x":["Comedy"],"xaxis":"x","y":[0.981245311327832],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"index=%{x}<br>recall@1=%{y}<extra></extra>","legendgroup":"Crime","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"Crime","offsetgroup":"Crime","orientation":"v","showlegend":true,"textposition":"auto","x":["Crime"],"xaxis":"x","y":[0.9638888888888889],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"index=%{x}<br>recall@1=%{y}<extra></extra>","legendgroup":"Documentary","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"Documentary","offsetgroup":"Documentary","orientation":"v","showlegend":true,"textposition":"auto","x":["Documentary"],"xaxis":"x","y":[0.9788732394366197],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"index=%{x}<br>recall@1=%{y}<extra></extra>","legendgroup":"Drama","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"Drama","offsetgroup":"Drama","orientation":"v","showlegend":true,"textposition":"auto","x":["Drama"],"xaxis":"x","y":[0.971191135734072],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"index=%{x}<br>recall@1=%{y}<extra></extra>","legendgroup":"Family","marker":{"color":"#B6E880","pattern":{"shape":""}},"name":"Family","offsetgroup":"Family","orientation":"v","showlegend":true,"textposition":"auto","x":["Family"],"xaxis":"x","y":[0.9875],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"index=%{x}<br>recall@1=%{y}<extra></extra>","legendgroup":"Fantasy","marker":{"color":"#FF97FF","pattern":{"shape":""}},"name":"Fantasy","offsetgroup":"Fantasy","orientation":"v","showlegend":true,"textposition":"auto","x":["Fantasy"],"xaxis":"x","y":[1.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"index=%{x}<br>recall@1=%{y}<extra></extra>","legendgroup":"History","marker":{"color":"#FECB52","pattern":{"shape":""}},"name":"History","offsetgroup":"History","orientation":"v","showlegend":true,"textposition":"auto","x":["History"],"xaxis":"x","y":[0.9210526315789473],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"index=%{x}<br>recall@1=%{y}<extra></extra>","legendgr ...

# %%
import statistics

# %%
statistics.mean([ x[0] for x in metrics[["recall@1"]].values.tolist()])
# Out:
# 0.9770602564180475

# %%
statistics.mean([ x[0] for x in metrics[["majority@5"]].values.tolist()])
# Out:
# 0.7758067652164634
